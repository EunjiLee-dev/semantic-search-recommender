# %%
import pandas as pd

df = pd.read_csv("../data/processed/poi_clean.csv")

sample = df.head(5000)

print("WiFi:")
print(sample["WiFi"].value_counts(dropna=False))

print("\nReservations:")
print(sample["RestaurantsReservations"].value_counts(dropna=False))

print("\nDelivery:")
print(sample["RestaurantsDelivery"].value_counts(dropna=False))

print("\nParking (raw):")
print(sample["BusinessParking"].head(10))
# Out:
# WiFi:
# WiFi
# NaN        3185
# u'free'     909
# u'no'       455
# 'free'      245
# 'no'        184
# u'paid'      17
# 'paid'        5
# Name: count, dtype: int64
#
# Reservations:
# RestaurantsReservations
# NaN      3733
# False     908
# True      359
# Name: count, dtype: int64
#
# Delivery:
# RestaurantsDelivery
# NaN      3447
# True     1118
# False     435
# Name: count, dtype: int64
#
# Parking (raw):
# 0                                                  NaN
# 1    {'garage': False, 'street': True, 'validated':...
# 2    {'garage': None, 'street': None, 'validated': ...
# 3                                                  NaN
# 4    {'garage': False, 'street': False, 'validated'...
# 5                                                  NaN
# 6    {'garage': False, 'street': False, 'validated'...
# 7    {'garage': False, 'street': False, 'validated'...
# 8    {'garage': False, 'street': False, 'validated'...
# 9    {'garage': None, 'street': False, 'validated':...
# ...
